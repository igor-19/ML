# %% [markdown]
# ### https://www.kaggle.com/c/tabular-playground-series-apr-2021

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import time

import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
with open('train.csv') as t:
    for _ in range(3):
        print(t.readline())
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked
#
# 0,1,1,"Oconnor, Frankie",male,,2,0,209245,27.14,C12239,S
#
# 1,0,3,"Bryan, Drew",male,,0,0,27323,13.35,,S

# %%
ds = pd.read_csv('train.csv', delimiter=',')

# %%
ds.head(3)
# Out:
#    PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  Parch  \
# 0            0         1       1  Oconnor, Frankie  male   NaN      2      0
# 1            1         0       3       Bryan, Drew  male   NaN      0      0
# 2            2         0       3    Owens, Kenneth  male  0.33      1      2
#
#       Ticket   Fare   Cabin Embarked
# 0     209245  27.14  C12239        S
# 1      27323  13.35     NaN        S
# 2  CA 457703  71.29     NaN        S

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  object
#  5   Age          96708 non-null   float64
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       95377 non-null   object
#  9   Fare         99866 non-null   float64
#  10  Cabin        32134 non-null   object
#  11  Embarked     99750 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 9.2+ MB

# %%
ds.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
plt.pie(ds.Survived.value_counts(), explode=(0.05, 0.0), autopct='%1.1f%%', startangle=95)
plt.subplot(122)
sns.countplot(ds.Survived)
plt.show()

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(16, 5))
sns.heatmap(ds.corr(), annot=True, fmt='0.4f', cmap='Blues');

# %%
(ds.isnull().sum() / ds.shape[0]) * 100
# Out:
# PassengerId     0.000
# Survived        0.000
# Pclass          0.000
# Name            0.000
# Sex             0.000
# Age             3.292
# SibSp           0.000
# Parch           0.000
# Ticket          4.623
# Fare            0.134
# Cabin          67.866
# Embarked        0.250
# dtype: float64

# %%
plt.figure(figsize=(16, 8))
plt.subplot(121)
sns.heatmap(ds.isnull().sum().to_frame(), annot=True, fmt='d', cmap='Blues')
plt.title('number of missing')
plt.subplot(122)
sns.heatmap(((ds.isnull().sum() / ds.shape[0]) * 100).to_frame(), annot=True, fmt='.2f', cmap='Blues')
plt.title('percentage of missing');

# %% [markdown]
# ### columns

# %%
ds.Pclass.unique()
# Out:
# array([1, 3, 2])

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
sns.countplot(ds.Pclass[ds.Survived == 0])
plt.title('Survived == 0')
plt.subplot(122)
sns.countplot(ds.Pclass[ds.Survived == 1])
plt.title('Survived == 1')
plt.show()

# %%
len(ds.Name.unique()), ds.Name.unique()
# Out:
# (92144,
#  array(['Oconnor, Frankie', 'Bryan, Drew', 'Owens, Kenneth', ...,
#         'Childress, Charles', 'Caughlin, Thomas', 'Enciso, Tyler'],
#        dtype=object))

# %%
len(ds.Sex.unique()), ds.Sex.unique()
# Out:
# (2, array(['male', 'female'], dtype=object))

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
sns.countplot(ds.Sex[ds.Survived == 0])
plt.title('Survived == 0')
plt.subplot(122)
sns.countplot(ds.Sex[ds.Survived == 1])
plt.title('Survived == 1')
plt.show()

# %%
len(ds.Age.unique()), ds.Age.unique()
# Out:
# (174,
#  array([     nan, 3.30e-01, 1.90e+01, 2.50e+01, 3.50e+01, 7.00e+00,
#         6.00e+00, 2.70e+01, 6.60e+01, 3.10e+01, 6.00e+01, 3.60e+01,
#         5.00e+01, 4.40e+01, 5.70e+01, 5.30e+01, 4.30e+01, 6.10e+01,
#         1.70e+01, 3.90e+01, 5.90e+01, 2.30e+01, 2.10e+01, 2.60e+01,
#         5.00e+00, 6.70e+01, 5.40e+01, 6.90e+01, 2.20e+01, 6.80e+01,
#         7.10e+01, 6.30e+01, 4.70e+01, 4.50e+01, 3.40e+01, 3.00e+00,
#         2.80e+01, 3.70e+01, 6.40e+01, 5.80e+01, 5.60e+01, 4.00e+01,
#         3.80e+01, 2.00e+01, 8.00e+00, 7.00e+01, 1.10e+01, 4.90e+01,
#         5.20e+01, 4.80e+01, 4.10e+01, 3.20e+01, 6.20e+01, 5.50e+01,
#         6.50e+01, 4.60e+01, 2.00e+00, 4.20e+01, 2.90e+01, 5.10e+01,
#         1.40e+01, 2.40e+01, 3.00e+01, 3.30e+01, 1.80e+01, 7.90e+01,
#         1.20e+01, 9.00e+00, 8.30e-01, 1.00e+00, 1.50e+01, 5.00e-01,
#         1.00e+01, 7.20e+01, 2.45e+01, 7.70e+01, 7.30e+01, 4.00e+00,
#         7.50e-01, 1.60e+01, 8.00e+01, 1.30e+01, 7.40e+01, 2.65e+01,
# ...

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
sns.countplot(ds.Age[ds.Survived == 0])
plt.title('Survived == 0')
plt.subplot(122)
sns.countplot(ds.Age[ds.Survived == 1])
plt.title('Survived == 1')
plt.show()

# %%
len(ds.SibSp.unique()), ds.SibSp.unique()
# Out:
# (7, array([2, 0, 1, 3, 4, 8, 5]))

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
sns.countplot(ds[ds.Survived == 0].SibSp)
plt.title('Survived == 0')
plt.subplot(122)
sns.countplot(ds[ds.Survived == 1].SibSp)
plt.title('Survived == 1');

# %%
len(ds.Parch.unique()), ds.Parch.unique()
# Out:
# (8, array([0, 2, 1, 4, 3, 5, 6, 9]))

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
sns.countplot(ds[ds.Survived == 0].Parch)
plt.title('Survived == 0')
plt.subplot(122)
sns.countplot(ds[ds.Survived == 1].Parch)
plt.title('Survived == 1');

# %%
len(ds.Ticket.unique()), ds.Ticket.unique()
# Out:
# (75332,
#  array(['209245', '27323', 'CA 457703', ..., 'PC 15008', '458654',
#         '458074'], dtype=object))

# %%
len(ds.Fare.unique()), ds.Fare.unique()
# Out:
# (15936, array([ 27.14,  13.35,  71.29, ..., 246.1 , 225.51,   4.06]))

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
plt.hist(ds.Fare[ds.Survived == 0], bins=100)
plt.title('Survived == 0')
plt.subplot(122)
plt.hist(ds.Fare[ds.Survived == 1], bins=100)
plt.title('Survived == 1')
plt.show()

# %%
len(ds.Embarked.unique()), ds.Embarked.unique()
# Out:
# (4, array(['S', 'C', 'Q', nan], dtype=object))

# %%
plt.figure(figsize=(16, 5))
plt.subplot(121)
sns.countplot(ds.Embarked[ds.Survived == 0])
plt.title('Survived == 0')
plt.subplot(122)
sns.countplot(ds.Embarked[ds.Survived == 1])
plt.title('Survived == 1')
plt.show()

# %%
columns_cat = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']
columns_numeric = ['Age', 'Fare']
target = ['Survived']

# %% [markdown]
# ### Filling missing values

# %%
def filling_missing_values_mean(data, column):
    
    data[column][data.Survived == 0] = data[column].fillna(data[column][data.Survived == 0].mean())
    data[column][data.Survived == 1] = data[column].fillna(data[column][data.Survived == 1].mean())
    
    return data

# %%
ds = filling_missing_values_mean(ds, 'Age')

# %%
ds = filling_missing_values_mean(ds, 'Fare')

# %%
ds = ds[columns_cat + columns_numeric + target]
ds.dropna(axis=0, inplace=True)

# %%
ds.columns
# Out:
# Index(['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Age', 'Fare',
#        'Survived'],
#       dtype='object')

# %%
ds.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Embarked    0
# Age         0
# Fare        0
# Survived    0
# dtype: int64

# %%
ds.shape
# Out:
# (99750, 8)

# %%
X = ds.drop('Survived', axis=1)
y = ds.Survived

# %%
X.shape, y.shape
# Out:
# ((99750, 7), (99750,))

# %% [markdown]
# ### Scaler

# %%
from sklearn.preprocessing import StandardScaler, normalize

# %%
scaler = StandardScaler()

# %%
scaler.fit(X[columns_numeric])
# Out:
# StandardScaler()

# %%
X_scaled = X.copy(deep=True)

# %%
X_scaled[columns_numeric] = scaler.transform(X[columns_numeric])

# %%
X_scaled = pd.get_dummies(X_scaled, columns=columns_cat, drop_first=True, prefix_sep='_')

# %%
from sklearn.decomposition import PCA
from MulticoreTSNE import MulticoreTSNE as TSNE

# %%
pca = PCA()

# %%
pca.fit(X_scaled)
# Out:
# PCA()

# %%
X_scaled.shape
# Out:
# (99750, 20)

# %%
plt.figure(figsize=(16, 5))
plt.plot(range(1, 21), np.cumsum(pca.explained_variance_ratio_), marker='*');

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.33637948, 0.5343875 , 0.66735678, 0.75530974, 0.81663889,
#        0.86983066, 0.90679634, 0.9322619 , 0.95524595, 0.97138622,
#        0.9830364 , 0.98818574, 0.99143797, 0.9946376 , 0.99609336,
#        0.99727071, 0.99818386, 0.99900277, 0.99962512, 1.        ])

# %%
idx = np.random.choice(X_scaled.index, size=10000)
X_sample = X_scaled.loc[idx]
y_sample = y.loc[idx]

# %%
tsne = TSNE(n_components=2, perplexity=5, random_state=42, n_jobs=-1)

# %%
# %%time
X_tsne = tsne.fit_transform(X_sample)
# Out:
# CPU times: user 3min 29s, sys: 1min 18s, total: 4min 47s
# Wall time: 1min 14s

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=10, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 3min 33s, sys: 1min 19s, total: 4min 52s
# Wall time: 1min 15s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=20, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 3min 57s, sys: 1min 19s, total: 5min 16s
# Wall time: 1min 21s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=25, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 15s, sys: 1min 18s, total: 5min 33s
# Wall time: 1min 29s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=30, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 16s, sys: 1min 18s, total: 5min 35s
# Wall time: 1min 27s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=35, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 23s, sys: 1min 20s, total: 5min 43s
# Wall time: 1min 27s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=40, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 23s, sys: 1min 20s, total: 5min 44s
# Wall time: 1min 24s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=50, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 27s, sys: 1min 21s, total: 5min 48s
# Wall time: 1min 23s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=60, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 28s, sys: 1min 22s, total: 5min 51s
# Wall time: 1min 18s

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=70, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_sample, legend='full');
# Out:
# CPU times: user 4min 39s, sys: 1min 21s, total: 6min 1s
# Wall time: 1min 20s

# %%
pca = PCA(n_components=12)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape[0]
# Out:
# 99750

# %%
y.reset_index(drop=True, inplace=True)

# %%
idx = np.random.randint(X_pca.shape[0], size=20000)
X_pca_sample = X_pca[idx, :]
y_pca_sample = y.loc[idx]

# %%
# %%time
tsne = TSNE(n_components=2, perplexity=20, random_state=42, n_jobs=-1)

X_tsne = tsne.fit_transform(X_pca_sample)

plt.figure(figsize=(10, 10))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1],
               hue=y_pca_sample, legend='full');
# Out:
# CPU times: user 7min 30s, sys: 1min 23s, total: 8min 53s
# Wall time: 3min 9s
