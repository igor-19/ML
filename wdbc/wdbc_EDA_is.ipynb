# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
with open('wdbc.data', 'r') as t:
    for _ in range(5):
        data_line = t.readline()

# %%
data_line = data_line.strip('\n').split(',')

# %%
len(data_line)
# Out:
# 32

# %%
column_name = []
for i in range(len(data_line)):
    name_column = 'col_' + str(i)
    column_name.append(name_column)

# %%
print(columns)
# Out:
# ['col_0', 'col_1', 'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7', 'col_8', 'col_9', 'col_10', 'col_11', 'col_12', 'col_13', 'col_14', 'col_15', 'col_16', 'col_17', 'col_18', 'col_19', 'col_20', 'col_21', 'col_22', 'col_23', 'col_24', 'col_25', 'col_26', 'col_27', 'col_28', 'col_29', 'col_30', 'col_31']

# %%
df = pd.read_csv('wdbc.data', sep=',', names=column_name)

# %%
df.head()
# Out:
#       col_0 col_1  col_2  col_3   col_4   col_5    col_6    col_7   col_8  \
# 0    842302     M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517     M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903     M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301     M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402     M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#      col_9  ...  col_22  col_23  col_24  col_25  col_26  col_27  col_28  \
# 0  0.14710  ...   25.38   17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.07017  ...   24.99   23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.12790  ...   23.57   25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.10520  ...   14.91   26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.10430  ...   22.54   16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#    col_29  col_30   col_31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %%
df.shape, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_0   569 non-null    int64
#  1   col_1   569 non-null    object
#  2   col_2   569 non-null    float64
#  3   col_3   569 non-null    float64
#  4   col_4   569 non-null    float64
#  5   col_5   569 non-null    float64
#  6   col_6   569 non-null    float64
#  7   col_7   569 non-null    float64
#  8   col_8   569 non-null    float64
#  9   col_9   569 non-null    float64
#  10  col_10  569 non-null    float64
#  11  col_11  569 non-null    float64
#  12  col_12  569 non-null    float64
#  13  col_13  569 non-null    float64
#  14  col_14  569 non-null    float64
#  15  col_15  569 non-null    float64
#  16  col_16  569 non-null    float64
#  17  col_17  569 non-null    float64
#  18  col_18  569 non-null    float64
#  19  col_19  569 non-null    float64
# ...

# %%
df.describe()
# Out:
#               col_0       col_2       col_3       col_4        col_5  \
# count  5.690000e+02  569.000000  569.000000  569.000000   569.000000
# mean   3.037183e+07   14.127292   19.289649   91.969033   654.889104
# std    1.250206e+08    3.524049    4.301036   24.298981   351.914129
# min    8.670000e+03    6.981000    9.710000   43.790000   143.500000
# 25%    8.692180e+05   11.700000   16.170000   75.170000   420.300000
# 50%    9.060240e+05   13.370000   18.840000   86.240000   551.100000
# 75%    8.813129e+06   15.780000   21.800000  104.100000   782.700000
# max    9.113205e+08   28.110000   39.280000  188.500000  2501.000000
#
#             col_6       col_7       col_8       col_9      col_10  ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.096360    0.104341    0.088799    0.048919    0.181162  ...
# std      0.014064    0.052813    0.079720    0.038803    0.027414  ...
# ...

# %%
df.describe(include=['object'])
# Out:
#        col_1
# count    569
# unique     2
# top        B
# freq     357

# %%
df.corr()
# Out:
#            col_0     col_2     col_3     col_4     col_5     col_6     col_7  \
# col_0   1.000000  0.074626  0.099770  0.073159  0.096893 -0.012968  0.000096
# col_2   0.074626  1.000000  0.323782  0.997855  0.987357  0.170581  0.506124
# col_3   0.099770  0.323782  1.000000  0.329533  0.321086 -0.023389  0.236702
# col_4   0.073159  0.997855  0.329533  1.000000  0.986507  0.207278  0.556936
# col_5   0.096893  0.987357  0.321086  0.986507  1.000000  0.177028  0.498502
# col_6  -0.012968  0.170581 -0.023389  0.207278  0.177028  1.000000  0.659123
# col_7   0.000096  0.506124  0.236702  0.556936  0.498502  0.659123  1.000000
# col_8   0.050080  0.676764  0.302418  0.716136  0.685983  0.521984  0.883121
# col_9   0.044158  0.822529  0.293464  0.850977  0.823269  0.553695  0.831135
# col_10 -0.022114  0.147741  0.071401  0.183027  0.151293  0.557775  0.602641
# col_11 -0.052511 -0.311631 -0.076437 -0.261477 -0.283110  0.584792  0.565369
# ...

# %%
corr_field = []
for i in df.corr():
    for j in df.corr().index[df.corr()[i] > 0.7]   
    pass
# Out:
#   File "<ipython-input-37-a9c91bcbf151>", line 3
#     for j in df.corr().
#                            ^
# SyntaxError: invalid syntax

# %%
df.corr().index[df.corr()['col_1'] > 0.1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-e216b02a5cc5> in <module>
# ...
